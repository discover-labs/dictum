# %% [markdown]
# The main way to retrieve data from a Dictum project is the Python API. You can explore
# your metrics in Jupyter or retrieve the data as a Pandas Dataframe for further analysis.
#
# In this and other example notebooks, we'll be using a
# [sample Chinook database](https://github.com/lerocha/chinook-database) and a
# corresponding Dictum example project.

# %%
from dictum import Project

project = Project.example("chinook")

# %% [markdown]
# ## Exploring the project
#
# You can interface with the project by using the resulting `project` object. Let's see
# which metrics and dimensions are in the project first.

# %%
revenue = project.model.metrics["revenue"]
revenue
# Out:
# Metric(revenue)

# %%
revenue.str_expr
# Out:
# '$revenue'

# %%
revenue.name
# Out:
# 'Revenue'

# %%
revenue.format
# Out:
# FormatConfig(kind='currency', pattern=None, skeleton=None, currency='USD')

# %%
import altair as alt

project.chart().mark_area().encode(
    x=alt.X(project.dimensions.Quarter, timeUnit="yearquarter"),
    y=project.m.revenue,
    color=project.d.customer_country,
)
# Out:
# alt.Chart(...)

# %%
from dictum import Project
project = Project.example("chinook")
project.select("revenue.percent").by("genre").where("music")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Genre</th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alternative</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alternative &amp; Punk</td>
#       <td>11%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Blues</td>
#       <td>3%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bossa Nova</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Classical</td>
#       <td>2%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Easy Listening</td>
#       <td>0%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Electronica/Dance</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Heavy Metal</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Hip Hop/Rap</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Jazz</td>
#       <td>4%</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Latin</td>
#       <td>18%</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Metal</td>
#       <td>12%</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Pop</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>R&amp;B/Soul</td>
#       <td>2%</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Reggae</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Rock</td>
#       <td>39%</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Rock And Roll</td>
#       <td>0%</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Soundtrack</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>World</td>
#       <td>1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import altair as alt

(
    project.chart()
    .mark_bar()
    .encode(
        x=alt.X(project.m.revenue),
        y=alt.Y(project.d.genre),
    )
)
# Out:
# alt.Chart(...)

# %%
project.dimensions
# Out:
# <div style="max-height: 20rem; overflow-y: scroll;">
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Country</h3>
# <code>:country</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Order's Customer Country</h3>
# <code>:order_customer_country</code>
#
#
# <p>Duplicate of Customer Country, used for tests</p>
#
#
#
# <p>
# <code>:customer_country</code>
# on table invoice_items: <code>invoice_items</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Month After First Order</h3>
# <code>:first_order_cohort_month</code>
#
#
#
#
# <p>
# <code>datediff('month', :customer_first_sale_date, :invoice_date)</code>
# on table invoice_items: <code>invoice_items</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Months Since First Order</h3>
# <code>:order_cohort</code>
#
#
#
#
# <p>
# <code>datediff('month', :customer_first_sale_date, :invoice_date)</code>
# on table invoice_items: <code>invoice_items</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Album</h3>
# <code>:album</code>
#
#
#
#
# <p>
# <code>Title</code>
# on table albums: <code>albums</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer Country</h3>
# <code>:customer_country</code>
#
#
#
#
# <p>
# <code>Country</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer City</h3>
# <code>:customer_city</code>
#
#
#
#
# <p>
# <code>City</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer's Total Orders Amount</h3>
# <code>:customer_orders_amount</code>
#
#
#
#
# <p>
# <code>$revenue</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer's Total Orders Amount ($10 bins)</h3>
# <code>:customer_orders_amount_10_bins</code>
#
#
#
#
# <p>
# <code>:customer_orders_amount // 10 * 10</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer's First Sale Date</h3>
# <code>:customer_first_sale_date</code>
#
#
#
#
# <p>
# <code>$min_sale_date</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Invoice Date</h3>
# <code>:invoice_date</code>
#
#
#
#
# <p>
# <code>InvoiceDate</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Sale Datetime</h3>
# <code>:invoice_datetime</code>
#
#
# <p>User for testing purposes (type casting)</p>
#
#
#
# <p>
# <code>InvoiceDate</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Order Amount</h3>
# <code>:order_amount</code>
#
#
#
#
# <p>
# <code>Total</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Total Order Amount ($10 bins)</h3>
# <code>:order_amount_10_dollar_bins</code>
#
#
#
#
# <p>
# <code>Total // 10 * 10</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Invoice Year</h3>
# <code>:invoice_year</code>
#
#
#
#
# <p>
# <code>datepart('year', :invoice_date)</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Invoice Date is in Leap Year</h3>
# <code>:leap_year</code>
#
#
#
#
# <p>
# <code>if(
#   :invoice_year % 400 == 0, 'Yes',
#   :invoice_year % 100 != 0 and :invoice_year % 4 == 0, 'Yes',
#   'No'
# )
# </code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Track Length (10-second bins)</h3>
# <code>:track_length_10s_bins</code>
#
#
#
#
# <p>
# <code>Milliseconds / 1000 // 10 * 10</code>
# on table tracks: <code>tracks</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Artist</h3>
# <code>:artist</code>
#
#
#
#
# <p>
# <code>Name</code>
# on table artists: <code>artists</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Genre</h3>
# <code>:genre</code>
#
#
#
#
# <p>
# <code>Name</code>
# on table genres: <code>genres</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Media Type</h3>
# <code>:media_type</code>
#
#
#
#
# <p>
# <code>Name</code>
# on table media_types: <code>media_types</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Manager's Title</h3>
# <code>:manager_title</code>
#
#
#
#
# <p>
# <code>manager.Title</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Manager's Name</h3>
# <code>:manager_name</code>
#
#
#
#
# <p>
# <code>manager.LastName</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Name</h3>
# <code>:employee_name</code>
#
#
#
#
# <p>
# <code>LastName</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Title</h3>
# <code>:employee_title</code>
#
#
#
#
# <p>
# <code>Title</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Employee Country</h3>
# <code>:employee_country</code>
#
#
#
#
# <p>
# <code>Country</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Employee Revenue</h3>
# <code>:employee_revenue</code>
#
#
#
#
# <p>
# <code>$revenue</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Time</h3>
# <code>:Time</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Year</h3>
# <code>:Year</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Quarter</h3>
# <code>:Quarter</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Month</h3>
# <code>:Month</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Week</h3>
# <code>:Week</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Day</h3>
# <code>:Day</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Date</h3>
# <code>:Date</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Hour</h3>
# <code>:Hour</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Minute</h3>
# <code>:Minute</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Second</h3>
# <code>:Second</code>
#
#
#
#
# </p>
#
# </div>

# %%
project.metrics
# Out:
# <div style="max-height: 20rem; overflow-y: scroll;">
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Revenue for "Rock" Genre</h3>
# <code>$rock_revenue</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Number of Employees</h3>
# <code>$n_employees</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Number of Customers</h3>
# <code>$n_customers</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Averate Sold Unit Price</h3>
# <code>$avg_sold_unit_price</code>
#
#
# <p>Average price of a track that we sold.</p>
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Unique Paying Customers</h3>
# <code>$unique_paying_customers</code>
#
#
# <p>Number of unique users who made an order.
# </p>
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Revenue</h3>
# <code>$revenue</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Number of Items Sold</h3>
# <code>$items_sold</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Average Revenue per Paying Customer</h3>
# <code>$arppu</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Music Revenue</h3>
# <code>$music_revenue</code>
#
#
# <p>Revenue, but only for music files. Used for demonstrating
# filtered measures.
# </p>
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Sum of Track Length (Seconds)</h3>
# <code>$track_length</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Number of Tracks</h3>
# <code>$track_count</code>
#
#
# <p>Total Number of Tracks in the Library.
# </p>
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Average Track Length (Seconds)</h3>
# <code>$avg_track_length</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Average Track Price</h3>
# <code>$avg_track_price</code>
#
#
# <p>Average price of a track in our library. For average sold item size, see
# Average Sold Unit Price.
# </p>
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Revenue per Track in the Library</h3>
# <code>$revenue_per_track</code>
#
#
#
#
# </p>
#
# </div>

# %% [markdown]
# Now we can start querying Dictum. Metrics and Dimensions are stored as attributes to
# `project.metrics` and `project.dimensions`. To make it easier to use them interactively,
# it's good to give them shorter names.

# %%
m, d = project.metrics, project.dimensions

# %% [markdown]
# ## Selecting a metric
#
# Now we can start exploring the data. Let's see the total value for `Revenue`.

# %%
project.select(m.revenue)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>$2,328.60</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Metrics and dimensions can be specified as objects, like above, or by passing their
# identifier as a string.

# %%
project.select("revenue")  # this is the same as the above
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>$2,328.60</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Notice that the values are formatted according to the format specification of the
# `revenue` metric.

# %%
m.revenue.calculation.format
# Out:
# FormatConfig(kind='currency', pattern=None, skeleton=None, currency='USD')

# %% [markdown]
# ## Grouping by dimension
#
# We can group the metric by any dimension that's applicable for it.

# %%
project.select(m.revenue).by(d.genre)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Genre</th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alternative</td>
#       <td>$13.86</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alternative &amp; Punk</td>
#       <td>$241.56</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Blues</td>
#       <td>$60.39</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bossa Nova</td>
#       <td>$14.85</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Classical</td>
#       <td>$40.59</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Comedy</td>
#       <td>$17.91</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Drama</td>
#       <td>$57.71</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Easy Listening</td>
#       <td>$9.90</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Electronica/Dance</td>
#       <td>$11.88</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Heavy Metal</td>
#       <td>$11.88</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Pop</td>
#       <td>$27.72</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>R&amp;B/Soul</td>
#       <td>$40.59</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Reggae</td>
#       <td>$29.70</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Rock</td>
#       <td>$826.65</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Rock And Roll</td>
#       <td>$5.94</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Sci Fi &amp; Fantasy</td>
#       <td>$39.80</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Science Fiction</td>
#       <td>$11.94</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Soundtrack</td>
#       <td>$19.80</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>TV Shows</td>
#       <td>$93.53</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>World</td>
#       <td>$12.87</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Time dimensions
#
# What about dates? Date is just like any other dimension. Let's group revenue by the
# generic `Year`.

# %%
project.select(m.revenue).by(d.Year)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Invoice Date</th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2009</td>
#       <td>$449.46</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2010</td>
#       <td>$481.45</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2011</td>
#       <td>$469.58</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2012</td>
#       <td>$477.53</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013</td>
#       <td>$450.58</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Filtering
#
# In addition to grouping, we can filter the data by any dimension.

# %%
(
    project.select(m.revenue)
    .by(d.invoice_date.datetrunc("year"))
    .where(d.genre == "Rock")
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Invoice Date</th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2009</td>
#       <td>$178.20</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2010</td>
#       <td>$155.43</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2011</td>
#       <td>$156.42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2012</td>
#       <td>$162.36</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2013</td>
#       <td>$174.24</td>
#     </tr>
#   </tbody>
# </table>

# %%
project.dimensions
# customer_orders_amount
# Out:
# <div style="max-height: 20rem; overflow-y: scroll;">
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Country</h3>
# <code>:country</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Order's Customer Country</h3>
# <code>:order_customer_country</code>
#
#
# <p>Duplicate of Customer Country, used for tests</p>
#
#
#
# <p>
# <code>:customer_country</code>
# on table invoice_items: <code>invoice_items</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Month After First Order</h3>
# <code>:first_order_cohort_month</code>
#
#
#
#
# <p>
# <code>datediff('month', :customer_first_sale_date, :invoice_date)</code>
# on table invoice_items: <code>invoice_items</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Months Since First Order</h3>
# <code>:order_cohort</code>
#
#
#
#
# <p>
# <code>datediff('month', :customer_first_sale_date, :invoice_date)</code>
# on table invoice_items: <code>invoice_items</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Album</h3>
# <code>:album</code>
#
#
#
#
# <p>
# <code>Title</code>
# on table albums: <code>albums</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer Country</h3>
# <code>:customer_country</code>
#
#
#
#
# <p>
# <code>Country</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer City</h3>
# <code>:customer_city</code>
#
#
#
#
# <p>
# <code>City</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer's Total Orders Amount</h3>
# <code>:customer_orders_amount</code>
#
#
#
#
# <p>
# <code>$revenue</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer's Total Orders Amount ($10 bins)</h3>
# <code>:customer_orders_amount_10_bins</code>
#
#
#
#
# <p>
# <code>:customer_orders_amount // 10 * 10</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Customer's First Sale Date</h3>
# <code>:customer_first_sale_date</code>
#
#
#
#
# <p>
# <code>$min_sale_date</code>
# on table customers: <code>customers</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Invoice Date</h3>
# <code>:invoice_date</code>
#
#
#
#
# <p>
# <code>InvoiceDate</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Sale Datetime</h3>
# <code>:invoice_datetime</code>
#
#
# <p>User for testing purposes (type casting)</p>
#
#
#
# <p>
# <code>InvoiceDate</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Order Amount</h3>
# <code>:order_amount</code>
#
#
#
#
# <p>
# <code>Total</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Total Order Amount ($10 bins)</h3>
# <code>:order_amount_10_dollar_bins</code>
#
#
#
#
# <p>
# <code>Total // 10 * 10</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Invoice Year</h3>
# <code>:invoice_year</code>
#
#
#
#
# <p>
# <code>datepart('year', :invoice_date)</code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Invoice Date is in Leap Year</h3>
# <code>:leap_year</code>
#
#
#
#
# <p>
# <code>if(
#   :invoice_year % 400 == 0, 'Yes',
#   :invoice_year % 100 != 0 and :invoice_year % 4 == 0, 'Yes',
#   'No'
# )
# </code>
# on table invoices: <code>invoices</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Track Length (10-second bins)</h3>
# <code>:track_length_10s_bins</code>
#
#
#
#
# <p>
# <code>Milliseconds / 1000 // 10 * 10</code>
# on table tracks: <code>tracks</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Artist</h3>
# <code>:artist</code>
#
#
#
#
# <p>
# <code>Name</code>
# on table artists: <code>artists</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Genre</h3>
# <code>:genre</code>
#
#
#
#
# <p>
# <code>Name</code>
# on table genres: <code>genres</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Media Type</h3>
# <code>:media_type</code>
#
#
#
#
# <p>
# <code>Name</code>
# on table media_types: <code>media_types</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Manager's Title</h3>
# <code>:manager_title</code>
#
#
#
#
# <p>
# <code>manager.Title</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Manager's Name</h3>
# <code>:manager_name</code>
#
#
#
#
# <p>
# <code>manager.LastName</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Name</h3>
# <code>:employee_name</code>
#
#
#
#
# <p>
# <code>LastName</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Support Rep's Title</h3>
# <code>:employee_title</code>
#
#
#
#
# <p>
# <code>Title</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Employee Country</h3>
# <code>:employee_country</code>
#
#
#
#
# <p>
# <code>Country</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Employee Revenue</h3>
# <code>:employee_revenue</code>
#
#
#
#
# <p>
# <code>$revenue</code>
# on table employees: <code>employees</code>
# </p>
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Time</h3>
# <code>:Time</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Year</h3>
# <code>:Year</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Quarter</h3>
# <code>:Quarter</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Month</h3>
# <code>:Month</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Week</h3>
# <code>:Week</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Day</h3>
# <code>:Day</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Date</h3>
# <code>:Date</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Hour</h3>
# <code>:Hour</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Minute</h3>
# <code>:Minute</code>
#
#
#
#
# </p>
#
# <p style="margin-bottom: 2rem;">
#
#
# <h3>Second</h3>
# <code>:Second</code>
#
#
#
#
# </p>
#
# </div>

# %% [markdown]
# ## Dimension transforms
#
# A dimension doesn't always contain the exact level of granularity that you want. Let's
# take dates: sometimes you might want to group a metric by month, sometimes by day or
# quarter. To avoid creating a separate dimension for every level of granularity, Dictum
# provides dimension transforms. Transforms are special built-in functions that you can
# apply to a dimension to slightly modify how it works. The most common usage of transforms
# is specifying date granularity.
#
# You can find a list of all available transforms in the
# [query language reference](../../../reference/query_language/).

# %%
(
    project.select(m.revenue)
    .by(d.invoice_date.datetrunc("quarter"))
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Invoice Date</th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Q1 2009</td>
#       <td>$110.88</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Q2 2009</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Q3 2009</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Q4 2009</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Q1 2010</td>
#       <td>$143.86</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Q2 2010</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Q3 2010</td>
#       <td>$111.87</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Q4 2010</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Q1 2011</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Q2 2011</td>
#       <td>$144.86</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Q3 2011</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Q4 2011</td>
#       <td>$99.00</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Q1 2012</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Q2 2012</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Q3 2012</td>
#       <td>$133.95</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Q4 2012</td>
#       <td>$117.86</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Q1 2013</td>
#       <td>$102.96</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Q2 2013</td>
#       <td>$108.90</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Q3 2013</td>
#       <td>$112.86</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Q4 2013</td>
#       <td>$125.86</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Generic dates
#
# There are special time dimensions that we call _generic dates_. For example, the default
# time dimension for `revenue` is `invoice_date`. If we query _revenue by quarter_, Dictum
# understands that you really mean _revenue by quarter of invoice date_.

# %%
(
    project.select(m.revenue)
    .by(d.Quarter)
    .where(d.genre == "Rock", d.Time >= "2012-01-01")
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Invoice Date</th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Q1 2012</td>
#       <td>$43.56</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Q2 2012</td>
#       <td>$48.51</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Q3 2012</td>
#       <td>$51.48</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Q4 2012</td>
#       <td>$18.81</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Q1 2013</td>
#       <td>$29.70</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Q2 2013</td>
#       <td>$42.57</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Q3 2013</td>
#       <td>$47.52</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Q4 2013</td>
#       <td>$54.45</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Selecting multiple metrics
#
# You can select multiple metrics in the same query, even if they are computed from
# different tables in the database. The only limitation is that all dimensions in the query
# must be compatible with all the metrics that you selected.

# %%
m.track_count
# Out:
# <h3>Number of Tracks</h3>
# <code>:track_count</code>
#
#
# <p>Total Number of Tracks in the Library.
# </p>
#
#
#
# <p>
# <code>count()</code>
# on table tracks: <code>tracks</code>
# </p>

# %%
m.revenue
# Out:
# <h3>Revenue</h3>
# <code>:revenue</code>
#
#
#
#
# <p>
# <code>sum(UnitPrice * Quantity)</code>
# on table invoice_items: <code>invoice_items</code>
# </p>

# %%
(
    project.select(
        m.revenue,
        m.track_count,
    )
    .by(d.genre)
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Genre</th>
#       <th>Revenue</th>
#       <th>Number of Tracks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alternative</td>
#       <td>$13.86</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alternative &amp; Punk</td>
#       <td>$241.56</td>
#       <td>332</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Blues</td>
#       <td>$60.39</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bossa Nova</td>
#       <td>$14.85</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Classical</td>
#       <td>$40.59</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Comedy</td>
#       <td>$17.91</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Drama</td>
#       <td>$57.71</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Easy Listening</td>
#       <td>$9.90</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Electronica/Dance</td>
#       <td>$11.88</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Heavy Metal</td>
#       <td>$11.88</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>R&amp;B/Soul</td>
#       <td>$40.59</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Reggae</td>
#       <td>$29.70</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Rock</td>
#       <td>$826.65</td>
#       <td>1,297</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Rock And Roll</td>
#       <td>$5.94</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Sci Fi &amp; Fantasy</td>
#       <td>$39.80</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Science Fiction</td>
#       <td>$11.94</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Soundtrack</td>
#       <td>$19.80</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>TV Shows</td>
#       <td>$93.53</td>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>World</td>
#       <td>$12.87</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Opera</td>
#       <td>$0.00</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Metric transforms
#
# Metrics can be transformed too. Unlike with dimensions, these are so-called
# _table transforms_. They are only valid in the context of a query with some exact
# dimensions.

# %%
(
    project.select(
        m.revenue,
        m.revenue.percent.name("Revenue (%)"),  # when there are no arguments to a transform, parentheses are optional
        m.revenue.total.name("Revenue (Total)")
    )
    .by(d.genre)
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Genre</th>
#       <th>Revenue</th>
#       <th>Revenue (%)</th>
#       <th>Revenue (Total)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alternative</td>
#       <td>$13.86</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alternative &amp; Punk</td>
#       <td>$241.56</td>
#       <td>10%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Blues</td>
#       <td>$60.39</td>
#       <td>3%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bossa Nova</td>
#       <td>$14.85</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Classical</td>
#       <td>$40.59</td>
#       <td>2%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Comedy</td>
#       <td>$17.91</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Drama</td>
#       <td>$57.71</td>
#       <td>2%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Easy Listening</td>
#       <td>$9.90</td>
#       <td>0%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Electronica/Dance</td>
#       <td>$11.88</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Heavy Metal</td>
#       <td>$11.88</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Pop</td>
#       <td>$27.72</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>R&amp;B/Soul</td>
#       <td>$40.59</td>
#       <td>2%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Reggae</td>
#       <td>$29.70</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Rock</td>
#       <td>$826.65</td>
#       <td>35%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Rock And Roll</td>
#       <td>$5.94</td>
#       <td>0%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Sci Fi &amp; Fantasy</td>
#       <td>$39.80</td>
#       <td>2%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Science Fiction</td>
#       <td>$11.94</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Soundtrack</td>
#       <td>$19.80</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>TV Shows</td>
#       <td>$93.53</td>
#       <td>4%</td>
#       <td>$2,328.60</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>World</td>
#       <td>$12.87</td>
#       <td>1%</td>
#       <td>$2,328.60</td>
#     </tr>
#   </tbody>
# </table>

# %%
(
    project.select(
        m.revenue,
        m.revenue.percent(within=[d.genre]).name("Revenue (%, genre)"),
        m.revenue.percent.name("Revenue (%, total)")
    )
    .by(d.genre, d.artist)
    .where(d.genre.isin("Rock", "Alternative & Punk"))
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Genre</th>
#       <th>Artist</th>
#       <th>Revenue</th>
#       <th>Revenue (%, genre)</th>
#       <th>Revenue (%, total)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alternative &amp; Punk</td>
#       <td>Audioslave</td>
#       <td>$4.95</td>
#       <td>2%</td>
#       <td>0%</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Alternative &amp; Punk</td>
#       <td>Body Count</td>
#       <td>$10.89</td>
#       <td>5%</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Alternative &amp; Punk</td>
#       <td>Faith No More</td>
#       <td>$32.67</td>
#       <td>14%</td>
#       <td>3%</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Alternative &amp; Punk</td>
#       <td>Foo Fighters</td>
#       <td>$4.95</td>
#       <td>2%</td>
#       <td>0%</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Alternative &amp; Punk</td>
#       <td>Green Day</td>
#       <td>$32.67</td>
#       <td>14%</td>
#       <td>3%</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Alternative &amp; Punk</td>
#       <td>JET</td>
#       <td>$6.93</td>
#       <td>3%</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Alternative &amp; Punk</td>
#       <td>Os Mutantes</td>
#       <td>$7.92</td>
#       <td>3%</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Alternative &amp; Punk</td>
#       <td>Pearl Jam</td>
#       <td>$5.94</td>
#       <td>2%</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Alternative &amp; Punk</td>
#       <td>R.E.M.</td>
#       <td>$24.75</td>
#       <td>10%</td>
#       <td>2%</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Alternative &amp; Punk</td>
#       <td>R.E.M. Feat. Kate Pearson</td>
#       <td>$8.91</td>
#       <td>4%</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>Rock</td>
#       <td>Terry Bozzio, Tony Levin &amp; Steve Stevens</td>
#       <td>$4.95</td>
#       <td>1%</td>
#       <td>0%</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>Rock</td>
#       <td>The Cult</td>
#       <td>$15.84</td>
#       <td>2%</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>Rock</td>
#       <td>The Doors</td>
#       <td>$3.96</td>
#       <td>0%</td>
#       <td>0%</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>Rock</td>
#       <td>The Police</td>
#       <td>$6.93</td>
#       <td>1%</td>
#       <td>1%</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>Rock</td>
#       <td>The Posies</td>
#       <td>$0.99</td>
#       <td>0%</td>
#       <td>0%</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>Rock</td>
#       <td>The Rolling Stones</td>
#       <td>$17.82</td>
#       <td>2%</td>
#       <td>2%</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>Rock</td>
#       <td>The Who</td>
#       <td>$18.81</td>
#       <td>2%</td>
#       <td>2%</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>Rock</td>
#       <td>U2</td>
#       <td>$90.09</td>
#       <td>11%</td>
#       <td>8%</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>Rock</td>
#       <td>Van Halen</td>
#       <td>$28.71</td>
#       <td>3%</td>
#       <td>3%</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Rock</td>
#       <td>Velvet Revolver</td>
#       <td>$5.94</td>
#       <td>1%</td>
#       <td>1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
project.ql("""
select revenue,
    revenue.total of (artist),
    revenue.total of (artist) within (genre)
where artist = 'Iron Maiden'
by genre, artist
""")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Genre</th>
#       <th>Artist</th>
#       <th>Revenue</th>
#       <th>Revenue</th>
#       <th>Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Blues</td>
#       <td>Iron Maiden</td>
#       <td>$3.96</td>
#       <td>$138.60</td>
#       <td>$3.96</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Heavy Metal</td>
#       <td>Iron Maiden</td>
#       <td>$11.88</td>
#       <td>$138.60</td>
#       <td>$11.88</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Metal</td>
#       <td>Iron Maiden</td>
#       <td>$69.30</td>
#       <td>$138.60</td>
#       <td>$69.30</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Rock</td>
#       <td>Iron Maiden</td>
#       <td>$53.46</td>
#       <td>$138.60</td>
#       <td>$53.46</td>
#     </tr>
#   </tbody>
# </table>
